# %%
import numpy as np

# %%
import pandas as pd

# %%
data = pd.read_csv("mriqc/bold.csv")
dup = pd.read_csv("mriqc/bold.csv")

# %%
print(data)
# Out:
#     subject_id  session_id task_id                    acq_id rec_id  run_id  \
# 0           qa    20161128    rest                        p2   moco     NaN
# 1           qa    20161128    rest                        p2    NaN     NaN
# 2           qa    20161128    rest                p2Xs4X35mm    NaN     NaN
# 3           qa    20161205    rest                        p2   moco     NaN
# 4           qa    20161205    rest                        p2    NaN     NaN
# 5           qa    20161205    rest                p2Xs4X35mm    NaN     NaN
# 6           qa    20161212    rest                        p2   moco     NaN
# 7           qa    20161212    rest                        p2    NaN     NaN
# 8           qa    20161212    rest                p2Xs4X35mm    NaN     NaN
# 9           qa    20161219    rest                        p2   moco     NaN
# 10          qa    20161219    rest                        p2    NaN     NaN
# ...

# %%
data.set_index([data.get("session_id"), data.get("acq_id")])
# Out:
#                                     subject_id  session_id task_id  \
# session_id acq_id
# 20161128   p2                               qa    20161128    rest
#            p2                               qa    20161128    rest
#            p2Xs4X35mm                       qa    20161128    rest
# 20161205   p2                               qa    20161205    rest
#            p2                               qa    20161205    rest
#            p2Xs4X35mm                       qa    20161205    rest
# 20161212   p2                               qa    20161212    rest
#            p2                               qa    20161212    rest
#            p2Xs4X35mm                       qa    20161212    rest
# 20161219   p2                               qa    20161219    rest
#            p2                               qa    20161219    rest
#            p2Xs4X35mm                       qa    20161219    rest
# 20170103   p2                               qa    20170103    rest
# ...

# %%
t1w = pd.read_csv("mriqc/T1w.csv")
two = pd.read_csv("mriqc/T1w.csv")

# %%
t1w.drop(columns=["session_id", "acq_id"])
# Out:
#    subject_id        cjv       cnr       efc          fber  fwhm_avg  \
# 0          qa   0.762358  1.366597  0.479177  60748.832031  6.124673
# 1          qa   1.053627  1.225509  0.485835  39186.089844  6.299788
# 2          qa  47.383209  0.028875  0.486745  35172.488281  6.713038
# 3          qa  47.127598  0.029174  0.487356  34710.335938  6.913474
# 4          qa   5.767219  0.205775  0.486915  39839.503906  7.086964
# 5          qa  17.943515  0.075232  0.488077  33549.718750  7.324702
# 6          qa   6.668865  0.173353  0.486142  37370.296875  6.694813
# 7          qa   0.907925  1.417284  0.484483  43211.464844  6.533037
# 8          qa   0.926266  1.410139  0.483593  49054.847656  6.317871
# 9          qa  28.830312  0.046955  0.489055  36277.007812  7.101411
# 10         qa  14.524251  0.093833  0.487248  33486.882812  7.071941
# 11         qa   3.687056  0.330681  0.489454  30147.998047  6.514754
# 12         qa   1.250175  1.054455  0.490525  30604.128906  6.778223
#
# ...

# %%
t1w.set_index([two.get("session_id"), two.get("acq_id")])
# Out:
#                   subject_id  session_id  acq_id        cjv       cnr  \
# session_id acq_id
# 20171030   MPRAGE         qa    20171030  MPRAGE   0.762358  1.366597
# 20171106   MPRAGE         qa    20171106  MPRAGE   1.053627  1.225509
# 20171113   MPRAGE         qa    20171113  MPRAGE  47.383209  0.028875
# 20171120   MPRAGE         qa    20171120  MPRAGE  47.127598  0.029174
# 20171127   MPRAGE         qa    20171127  MPRAGE   5.767219  0.205775
# 20171204   MPRAGE         qa    20171204  MPRAGE  17.943515  0.075232
# 20171218   MPRAGE         qa    20171218  MPRAGE   6.668865  0.173353
# 20180102   MPRAGE         qa    20180102  MPRAGE   0.907925  1.417284
# 20180108   MPRAGE         qa    20180108  MPRAGE   0.926266  1.410139
# 20180115   MPRAGE         qa    20180115  MPRAGE  28.830312  0.046955
# 20180122   MPRAGE         qa    20180122  MPRAGE  14.524251  0.093833
# 20180129   MPRAGE         qa    20180129  MPRAGE   3.687056  0.330681
# ...

# %%
hehe = t1w.corr(method='pearson')

# %%
import seaborn as sns

# %%
print(hehe)
# Out:
#                     session_id       cjv       cnr       efc      fber  \
# session_id            1.000000 -0.295356  0.237418  0.299536 -0.190128
# cjv                  -0.295356  1.000000 -0.681502  0.280849 -0.353704
# cnr                   0.237418 -0.681502  1.000000 -0.577981  0.640188
# efc                   0.299536  0.280849 -0.577981  1.000000 -0.954951
# fber                 -0.190128 -0.353704  0.640188 -0.954951  1.000000
# fwhm_avg             -0.018787  0.456002 -0.781229  0.655543 -0.636156
# fwhm_x               -0.052235  0.435536 -0.734740  0.656779 -0.681763
# fwhm_y                0.067267  0.447809 -0.805952  0.679552 -0.673346
# fwhm_z               -0.084257  0.438039 -0.716802  0.561136 -0.488324
# icvs_csf              0.068724 -0.853181  0.691755 -0.307150  0.375765
# icvs_gm              -0.084531  0.856656 -0.735787  0.353203 -0.421198
# icvs_wm               0.209807 -0.621689  0.928034 -0.684696  0.725436
# ...

# %%
sns.jointplot(data=data, x=data.keys(), y=data.index, kind='hex', color='g')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-d92ebd4d2288> in <module>()
# ----> 1 sns.jointplot(data=data, x=data.keys(), y=data.index, kind='hex', color='g')
#
# /anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2239     grid = JointGrid(x, y, data, dropna=dropna,
#    2240                      size=size, ratio=ratio, space=space,
# -> 2241                      xlim=xlim, ylim=ylim)
#    2242
#    2243     # Plot the data using the grid
#
# /anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py in __init__(self, x, y, data, size, ratio, space, dropna, xlim, ylim)
#    1685         # Possibly drop NA
#    1686         if dropna:
# -> 1687             not_na = pd.notnull(x) & pd.notnull(y)
# ...

# %%
sns.heatmap(hehe, cmap=sns.diverging_palette(h_neg=256, h_pos=10, n=16, center="dark"))
